# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris.csv')
df1 = df.copy()
df2 = df.copy()

# %%
df1
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(data = df1)
# Out:
# <Axes: >

# %%
df1['sepalwidth'] = (df1['sepalwidth'] - df1['sepalwidth'].min()) / (df1['sepalwidth'].max() - df1['sepalwidth'].min())

# %%
df1
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1    0.625000          1.4         0.2     Iris-setosa
# 1            4.9    0.416667          1.4         0.2     Iris-setosa
# 2            4.7    0.500000          1.3         0.2     Iris-setosa
# 3            4.6    0.458333          1.5         0.2     Iris-setosa
# 4            5.0    0.666667          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7    0.416667          5.2         2.3  Iris-virginica
# 146          6.3    0.208333          5.0         1.9  Iris-virginica
# 147          6.5    0.416667          5.2         2.0  Iris-virginica
# 148          6.2    0.583333          5.4         2.3  Iris-virginica
# 149          5.9    0.416667          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(data = df1)
# Out:
# <Axes: >

# %%
q1 = df['sepalwidth'].quantile(0.25)
q3 = df['sepalwidth'].quantile(0.75)

iqr = q3 - q1

low = q1 - 1.5*iqr
high = q3 + 1.5*iqr

df = df.loc[(df['sepalwidth'] > low) & (df['sepalwidth'] < high)]

# %%
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
df2
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df2['sepalwidth'] = (df2['sepalwidth'] - df2['sepalwidth'].mean()) / df2['sepalwidth'].std()

# %%
df2
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1    1.028611          1.4         0.2     Iris-setosa
# 1            4.9   -0.124540          1.4         0.2     Iris-setosa
# 2            4.7    0.336720          1.3         0.2     Iris-setosa
# 3            4.6    0.106090          1.5         0.2     Iris-setosa
# 4            5.0    1.259242          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7   -0.124540          5.2         2.3  Iris-virginica
# 146          6.3   -1.277692          5.0         1.9  Iris-virginica
# 147          6.5   -0.124540          5.2         2.0  Iris-virginica
# 148          6.2    0.797981          5.4         2.3  Iris-virginica
# 149          5.9   -0.124540          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(data = df2)
# Out:
# <Axes: >
